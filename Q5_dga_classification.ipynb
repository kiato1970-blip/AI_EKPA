# %% [markdown]
# <a href="https://colab.research.google.com/github/kiato1970-blip/AI_EKPA/blob/main/Q5_dga_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# εγκατάσταση πακέτου pycaret (https://pycaret.org/)
# 1. Αναβάθμιση του pip
# !!pip install pycaret==3.3.2
# Out:
# ['Requirement already satisfied: pycaret==3.3.2 in /usr/local/lib/python3.12/dist-packages (3.3.2)',
#  'Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from pycaret==3.3.2) (7.34.0)',
#  'Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.12/dist-packages (from pycaret==3.3.2) (7.7.1)',
#  'Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.12/dist-packages (from pycaret==3.3.2) (4.67.3)',
#  'Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.12/dist-packages (from pycaret==3.3.2) (1.26.4)',
#  'Requirement already satisfied: pandas<2.2.0 in /usr/local/lib/python3.12/dist-packages (from pycaret==3.3.2) (2.1.4)',
#  'Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.12/dist-packages (from pycaret==3.3.2) (3.1.6)',
#  'Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from pycaret==3.3.2) (1.11.4)',
# ...

# %%
# εισαγωγή βιβλιοθηκών - πακέτων
import sys

# "Κοροϊδεύουμε" το σύστημα ότι τρέχουμε Python 3.11
sys.version_info = (3, 11, 0, 'final', 0)

import pycaret
from pycaret.classification import *

print("PyCaret loaded successfully!")

# import pycaret
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pycaret.classification import *
# Out:
# PyCaret loaded successfully!

# %%
# εισαγωγή του συνόλου δεδομένων
url = 'https://raw.githubusercontent.com/jimtak80/AI_EKPA/main/Data/dga_domain.csv'
df = pd.read_csv(url)
# έλεγχος σχήματος συνόλου δεδομένων
print(df.shape)
# Out:
# (117588, 6)

# %%
# ανακάτεμα των δεδομένων
df = df.sample(frac = 1)
print(df.head())
# Out:
#         length   entropy   alexa_grams   word_grams       diff  class
# 77654       11  2.913977     27.531364    35.736220  -8.204855  legit
# 25120       13  3.026987     49.051263    71.110715 -22.059452  legit
# 90780        9  2.947703     16.873453    23.803397  -6.929944  legit
# 24268        8  2.750000      8.342664    12.910345  -4.567681  legit
# 110952      22  3.970573     38.923221    52.574275 -13.651054    dga

# %%
# εγκατάσταση του συνόλου δεδομένων
#grid = setup(data=df, target=df.columns[-1], html=False, verbose=False)
grid = setup(data=df, target=df.columns[-1], html=False, verbose=True)
# Out:
#                     Description                         Value
# 0                    Session id                          2139
# 1                        Target                         class
# 2                   Target type                    Multiclass
# 3                Target mapping  dga: 0, legit: 1, suspect: 2
# 4           Original data shape                   (117588, 6)
# 5        Transformed data shape                   (117588, 6)
# 6   Transformed train set shape                    (82311, 6)
# 7    Transformed test set shape                    (35277, 6)
# 8              Numeric features                             5
# 9                    Preprocess                          True
# 10              Imputation type                        simple
# 11           Numeric imputation                          mean
# 12       Categorical imputation                          mode
# 13               Fold Generator               StratifiedKFold
# ...

# %%
# σύγκριση των διαθέσιμων μοντέλων ΜΜ
best = compare_models(cross_validation=False, n_select = 1)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.8869  0.9094  0.8869  0.8870
# gbc          Gradient Boosting Classifier    0.8864  0.9062  0.8864  0.8870
# xgboost         Extreme Gradient Boosting    0.8857  0.9078  0.8857  0.8848
# rf               Random Forest Classifier    0.8802  0.8936  0.8802  0.8763
# lr                    Logistic Regression    0.8733  0.8725  0.8733  0.8712
# knn                K Neighbors Classifier    0.8728  0.8636  0.8728  0.8677
# et                 Extra Trees Classifier    0.8714  0.8855  0.8714  0.8659
# svm                   SVM - Linear Kernel    0.8698  0.0000  0.8698  0.8688
# qda       Quadratic Discriminant Analysis    0.8547  0.8754  0.8547  0.8536
# lda          Linear Discriminant Analysis    0.8503  0.8572  0.8503  0.8544
# ridge                    Ridge Classifier    0.8325  0.0000  0.8325  0.8412
# ...

# %%
# αναφορά των υπερπαραμέτρων του μοντέλου με την υψηλότερη απόδοση
print(best)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=2139, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
# μέτρα αξιολόγησης του μοντέλου με την υψηλότερη απόδοση
evaluate_model(best)
#plot_model(best_model, plot='class_report')
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
